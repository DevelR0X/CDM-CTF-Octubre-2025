# %%
from pwn import remote, process

r = process(['python3', 'server.py'], level = 'error')

for _ in range(100):
    r.sendlineafter(b"Coloca tus compuertas: ", b"CX:1,0;CCX:0,1,2;CX:2,1;H:2")
    print(r.recvline().decode())
# Out:
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# Conquista limpia. Fragmento de Bóveda: CDM{73571nG_fl4g!}
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# Conquista limpia. Fragmento de Bóveda: CDM{73571nG_fl4g!}
#
# El circuito no cumplió con las condiciones…
#
# Conquista limpia. Fragmento de Bóveda: CDM{73571nG_fl4g!}
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# El circuito no cumplió con las condiciones…
#
# Conquista limpia. Fragmento de Bóveda: CDM{73571nG_fl4g!}
#
# El circuito no cumplió con las condiciones…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 7
#       5 for _ in range(100):
#       6     r.sendlineafter(b"Coloca tus compuertas: ", b"CX:1,0;CCX:0,1,2;CX:2,1;H:2")
# ----> 7     print(r.recvline().decode())
#
# File ~/miniconda3/envs/crypto/lib/python3.12/site-packages/pwnlib/tubes/tube.py:527, in tube.recvline(self, keepends, timeout)
#     465 r"""recvline(keepends=True, timeout=default) -> bytes
#     466
#     467 Receive a single line from the tube.
#    (...)
#     524     EOFError
#     525 """
#     526 try:
# --> 527     return self.recvuntil(self.newline, drop = not keepends, timeout = timeout)
#     528 except EOFError:
#     529     if not context.throw_eof_on_incomplete_line and self.buffer.size > 0:
#
# File ~/miniconda3/envs/crypto/lib/python3.12/site-packages/pwnlib/tubes/tube.py:341, in tube.recvuntil(self, delims, drop, timeout)
#     339 while self.countdown_active():
#     340     try:
# --> 341         res = self.recv(timeout=self.timeout)
#     342     except Exception:
#     343         self.unrecv(b''.join(data) + top)
#
# File ~/miniconda3/envs/crypto/lib/python3.12/site-packages/pwnlib/tubes/tube.py:106, in tube.recv(self, numb, timeout)
#      75 r"""recv(numb = 4096, timeout = default) -> bytes
#      76
#      77 Receives up to `numb` bytes of data from the tube, and returns
#    (...)
#     103         b'Hello, world'
#     104 """
#     105 numb = self.buffer.get_fill_size(numb)
# --> 106 return self._recv(numb, timeout) or b''
#
# File ~/miniconda3/envs/crypto/lib/python3.12/site-packages/pwnlib/tubes/tube.py:176, in tube._recv(self, numb, timeout)
#     172 numb = self.buffer.get_fill_size(numb)
#     174 # No buffered data, could not put anything in the buffer
#     175 # before timeout.
# --> 176 if not self.buffer and not self._fillbuffer(timeout):
#     177     return b''
#     179 return self.buffer.get(numb)
#
# File ~/miniconda3/envs/crypto/lib/python3.12/site-packages/pwnlib/tubes/tube.py:155, in tube._fillbuffer(self, timeout)
#     152 data = b''
#     154 with self.local(timeout):
# --> 155     data = self.recv_raw(self.buffer.get_fill_size())
#     157 if data and self.isEnabledFor(logging.DEBUG):
#     158     self.debug('Received %#x bytes:' % len(data))
#
# File ~/miniconda3/envs/crypto/lib/python3.12/site-packages/pwnlib/tubes/process.py:717, in process.recv_raw(self, numb)
#     714 if not self.connected_raw('recv'):
#     715     raise EOFError
# --> 717 if not self.can_recv_raw(self.timeout):
#     718     return ''
#     720 if IS_WINDOWS:
#
# File ~/miniconda3/envs/crypto/lib/python3.12/site-packages/pwnlib/tubes/process.py:778, in process.can_recv_raw(self, timeout)
#     775     if timeout is None:
#     776         return select.select([self.proc.stdout], [], []) == ([self.proc.stdout], [], [])
# --> 778     return select.select([self.proc.stdout], [], [], timeout) == ([self.proc.stdout], [], [])
#     779 except ValueError:
#     780     # Not sure why this isn't caught when testing self.proc.stdout.closed,
#     781     # but it's not.
#    (...)
#     784     #     return select.select([self.proc.stdout], [], [], timeout) == ([self.proc.stdout], [], [])
#     785     # ValueError: I/O operation on closed file
#     786     raise EOFError
#
# KeyboardInterrupt:
